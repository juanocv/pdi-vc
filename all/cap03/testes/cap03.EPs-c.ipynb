# %% [markdown]
# ### EP03_01 ☀️ Ajuste de Brilho e Contraste
#
# Aplicação em Visão Computacional.
#
# **Equação principal:**
#
# $$p' = clip(round(p))$$
#
# | Parâmetro | Descrição |
# |---|---|
# | L,C | Dimensões |
# | p | Intensidade |
#
# **Entrada:** dimensões e matriz.
#
# **Saída:** matriz processada.
#
# | Entrada | Saída | Observação |
# |---|---|---|
# | Exemplo | Exemplo | Teste |

# %%
from IPython.display import HTML
HTML("""
<div id='ep03_01_sim' style='background:#fef9ef;padding:12px;border-radius:12px'>
<b>EP03_01 - Ajuste de Brilho e Contraste</b>
</div>
<script>
function render_ep0301(){}
</script>
""")

# %%
# %%writefile EP03_01.py
# Código Python

# %%
TestSuite("EP03_01.py").run()

# %% [markdown]
# ### EP03_02 ➕ Soma Saturada de Imagens
#
# Aplicação em Visão Computacional.
#
# **Equação principal:**
#
# $$p' = clip(round(p))$$
#
# | Parâmetro | Descrição |
# |---|---|
# | L,C | Dimensões |
# | p | Intensidade |
#
# **Entrada:** dimensões e matriz.
#
# **Saída:** matriz processada.
#
# | Entrada | Saída | Observação |
# |---|---|---|
# | Exemplo | Exemplo | Teste |

# %%
from IPython.display import HTML
HTML("""
<div id='ep03_02_sim' style='background:#fef9ef;padding:12px;border-radius:12px'>
<b>EP03_02 - Soma Saturada de Imagens</b>
</div>
<script>
function render_ep0302(){}
</script>
""")

# %%
# %%writefile EP03_02.py
# Código Python

# %%
TestSuite("EP03_02.py").run()

# %% [markdown]
# ### EP03_03 ➖ Subtração de Imagens
#
# Aplicação em Visão Computacional.
#
# **Equação principal:**
#
# $$p' = clip(round(p))$$
#
# | Parâmetro | Descrição |
# |---|---|
# | L,C | Dimensões |
# | p | Intensidade |
#
# **Entrada:** dimensões e matriz.
#
# **Saída:** matriz processada.
#
# | Entrada | Saída | Observação |
# |---|---|---|
# | Exemplo | Exemplo | Teste |

# %%
from IPython.display import HTML
HTML("""
<div id='ep03_03_sim' style='background:#fef9ef;padding:12px;border-radius:12px'>
<b>EP03_03 - Subtração de Imagens</b>
</div>
<script>
function render_ep0303(){}
</script>
""")

# %%
# %%writefile EP03_03.py
# Código Python

# %%
TestSuite("EP03_03.py").run()

# %% [markdown]
# ### EP03_04 🎚️ Alpha Blending
#
# Aplicação em Visão Computacional.
#
# **Equação principal:**
#
# $$p' = clip(round(p))$$
#
# | Parâmetro | Descrição |
# |---|---|
# | L,C | Dimensões |
# | p | Intensidade |
#
# **Entrada:** dimensões e matriz.
#
# **Saída:** matriz processada.
#
# | Entrada | Saída | Observação |
# |---|---|---|
# | Exemplo | Exemplo | Teste |

# %%
from IPython.display import HTML
HTML("""
<div id='ep03_04_sim' style='background:#fef9ef;padding:12px;border-radius:12px'>
<b>EP03_04 - Alpha Blending</b>
</div>
<script>
function render_ep0304(){}
</script>
""")

# %%
# %%writefile EP03_04.py
# Código Python

# %%
TestSuite("EP03_04.py").run()

# %% [markdown]
# ### EP03_05 🧮 Operação AND Bit a Bit
#
# Aplicação em Visão Computacional.
#
# **Equação principal:**
#
# $$p' = clip(round(p))$$
#
# | Parâmetro | Descrição |
# |---|---|
# | L,C | Dimensões |
# | p | Intensidade |
#
# **Entrada:** dimensões e matriz.
#
# **Saída:** matriz processada.
#
# | Entrada | Saída | Observação |
# |---|---|---|
# | Exemplo | Exemplo | Teste |

# %%
from IPython.display import HTML
HTML("""
<div id='ep03_05_sim' style='background:#fef9ef;padding:12px;border-radius:12px'>
<b>EP03_05 - Operação AND Bit a Bit</b>
</div>
<script>
function render_ep0305(){}
</script>
""")

# %%
# %%writefile EP03_05.py
# Código Python

# %%
TestSuite("EP03_05.py").run()

# %% [markdown]
# ### EP03_06 🎭 Operação OR Bit a Bit
#
# Aplicação em Visão Computacional.
#
# **Equação principal:**
#
# $$p' = clip(round(p))$$
#
# | Parâmetro | Descrição |
# |---|---|
# | L,C | Dimensões |
# | p | Intensidade |
#
# **Entrada:** dimensões e matriz.
#
# **Saída:** matriz processada.
#
# | Entrada | Saída | Observação |
# |---|---|---|
# | Exemplo | Exemplo | Teste |

# %%
from IPython.display import HTML
HTML("""
<div id='ep03_06_sim' style='background:#fef9ef;padding:12px;border-radius:12px'>
<b>EP03_06 - Operação OR Bit a Bit</b>
</div>
<script>
function render_ep0306(){}
</script>
""")

# %%
# %%writefile EP03_06.py
# Código Python

# %%
TestSuite("EP03_06.py").run()

# %% [markdown]
# ### EP03_07 📊 Histograma de Intensidades
#
# Aplicação em Visão Computacional.
#
# **Equação principal:**
#
# $$p' = clip(round(p))$$
#
# | Parâmetro | Descrição |
# |---|---|
# | L,C | Dimensões |
# | p | Intensidade |
#
# **Entrada:** dimensões e matriz.
#
# **Saída:** matriz processada.
#
# | Entrada | Saída | Observação |
# |---|---|---|
# | Exemplo | Exemplo | Teste |

# %%
from IPython.display import HTML
HTML("""
<div id='ep03_07_sim' style='background:#fef9ef;padding:12px;border-radius:12px'>
<b>EP03_07 - Histograma de Intensidades</b>
</div>
<script>
function render_ep0307(){}
</script>
""")

# %%
# %%writefile EP03_07.py
# Código Python

# %%
TestSuite("EP03_07.py").run()

# %% [markdown]
# ### EP03_08 📈 CDF Acumulada
#
# Aplicação em Visão Computacional.
#
# **Equação principal:**
#
# $$p' = clip(round(p))$$
#
# | Parâmetro | Descrição |
# |---|---|
# | L,C | Dimensões |
# | p | Intensidade |
#
# **Entrada:** dimensões e matriz.
#
# **Saída:** matriz processada.
#
# | Entrada | Saída | Observação |
# |---|---|---|
# | Exemplo | Exemplo | Teste |

# %%
from IPython.display import HTML
HTML("""
<div id='ep03_08_sim' style='background:#fef9ef;padding:12px;border-radius:12px'>
<b>EP03_08 - CDF Acumulada</b>
</div>
<script>
function render_ep0308(){}
</script>
""")

# %%
# %%writefile EP03_08.py
# Código Python

# %%
TestSuite("EP03_08.py").run()

# %% [markdown]
# ### EP03_09 ✨ Equalização de Histograma
#
# Aplicação em Visão Computacional.
#
# **Equação principal:**
#
# $$p' = clip(round(p))$$
#
# | Parâmetro | Descrição |
# |---|---|
# | L,C | Dimensões |
# | p | Intensidade |
#
# **Entrada:** dimensões e matriz.
#
# **Saída:** matriz processada.
#
# | Entrada | Saída | Observação |
# |---|---|---|
# | Exemplo | Exemplo | Teste |

# %%
from IPython.display import HTML
HTML("""
<div id='ep03_09_sim' style='background:#fef9ef;padding:12px;border-radius:12px'>
<b>EP03_09 - Equalização de Histograma</b>
</div>
<script>
function render_ep0309(){}
</script>
""")

# %%
# %%writefile EP03_09.py
# Código Python

# %%
TestSuite("EP03_09.py").run()

# %% [markdown]
# ### EP03_10 🔍 Comparação de Histogramas
#
# Aplicação em Visão Computacional.
#
# **Equação principal:**
#
# $$p' = clip(round(p))$$
#
# | Parâmetro | Descrição |
# |---|---|
# | L,C | Dimensões |
# | p | Intensidade |
#
# **Entrada:** dimensões e matriz.
#
# **Saída:** matriz processada.
#
# | Entrada | Saída | Observação |
# |---|---|---|
# | Exemplo | Exemplo | Teste |

# %%
from IPython.display import HTML
HTML("""
<div id='ep03_10_sim' style='background:#fef9ef;padding:12px;border-radius:12px'>
<b>EP03_10 - Comparação de Histogramas</b>
</div>
<script>
function render_ep0310(){}
</script>
""")

# %%
# %%writefile EP03_10.py
# Código Python

# %%
TestSuite("EP03_10.py").run()
